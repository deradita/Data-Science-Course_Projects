# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
boston = pd.read_csv('Boston.csv')
boston
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
#  13  lstat       506 non-null    float64
#  14  medv        506 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %%
boston.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
del boston["Unnamed: 0"]

# %%
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
boston.columns = boston.columns.str.upper()
boston.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'BLACK', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO   BLACK  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
sns.pairplot(boston)

# %%
sns.countplot(x = 'TAX', data = boston)
# Out:
# <AxesSubplot:xlabel='TAX', ylabel='count'>

# %%
sns.heatmap(boston.corr(), annot=True,fmt='.1f')
# Out:
# <AxesSubplot:>

# %%
X = boston [['CRIM', 'ZN', 'INDUS', 'CHAS', 
                'NOX','RM', 'AGE', 'DIS', 'PTRATIO', 
               'BLACK', 'LSTAT', 'MEDV', 'TAX' ]]
#X = boston ['MEDV']
y = boston ['RM']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
                                                    random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# -8.881784197001252e-16

# %%
print(lm.coef_)
# Out:
# [-6.69542798e-17  1.88872077e-16  9.29089015e-17 -3.92348949e-16
#  -7.89095861e-15  1.00000000e+00  2.12661879e-17  1.43415466e-16
#   1.32180762e-16 -1.67483339e-17  3.35052782e-16 -2.04245582e-16
#  -8.01711906e-18]

# %%
coeff_df = pd.DataFrame(lm.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
#           Coefficient
# CRIM    -6.695428e-17
# ZN       1.888721e-16
# INDUS    9.290890e-17
# CHAS    -3.923489e-16
# NOX     -7.890959e-15
# RM       1.000000e+00
# AGE      2.126619e-17
# DIS      1.434155e-16
# PTRATIO  1.321808e-16
# BLACK   -1.674833e-17
# LSTAT    3.350528e-16
# MEDV    -2.042456e-16
# TAX     -8.017119e-18

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test, predictions)

# %%
sns.distplot((y_test-predictions), bins=50);
# Out:
# C:\Users\odita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))

print('MSE:', metrics.mean_squared_error(y_test, predictions))

print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 4.262672086652903e-15
# MSE: 2.9256619328665455e-29
# RMSE: 5.408938835729745e-15

# %%
test=pd.read_csv('test.csv')

# %%
test.head()
# Out:
#    Unnamed: 0      CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD  \
# 0           0   0.09299  0.0  25.65   0.0  0.581  5.961   92.9  2.0869   2.0
# 1           1  25.04610  0.0  18.10   0.0  0.693  5.987  100.0  1.5888  24.0
# 2           2   7.05042  0.0  18.10   0.0  0.614  6.103   85.1  2.0218  24.0
# 3           3   9.92485  0.0  18.10   0.0  0.740  6.251   96.6  2.1980  24.0
# 4           4   0.12269  0.0   6.91   0.0  0.448  6.069   40.0  5.7209   3.0
#
#      TAX  PTRATIO       B  LSTAT
# 0  188.0     19.1  378.09  17.93
# 1  666.0     20.2  396.90  26.77
# 2  666.0     20.2    2.52  23.29
# 3  666.0     20.2  388.52  16.44
# 4  233.0     17.9  389.39   9.55

# %%
del test["Unnamed: 0"]

# %%
test
# Out:
#          CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.09299  0.0  25.65   0.0  0.581  5.961   92.9  2.0869   2.0  188.0
# 1    25.04610  0.0  18.10   0.0  0.693  5.987  100.0  1.5888  24.0  666.0
# 2     7.05042  0.0  18.10   0.0  0.614  6.103   85.1  2.0218  24.0  666.0
# 3     9.92485  0.0  18.10   0.0  0.740  6.251   96.6  2.1980  24.0  666.0
# 4     0.12269  0.0   6.91   0.0  0.448  6.069   40.0  5.7209   3.0  233.0
# ..        ...  ...    ...   ...    ...    ...    ...     ...   ...    ...
# 97    2.92400  0.0  19.58   0.0  0.605  6.101   93.0  2.2834   5.0  403.0
# 98    0.17120  0.0   8.56   0.0  0.520  5.836   91.9  2.2110   5.0  384.0
# 99    4.34879  0.0  18.10   0.0  0.580  6.167   84.0  3.0334  24.0  666.0
# 100   2.73397  0.0  19.58   0.0  0.871  5.597   94.9  1.5257   5.0  403.0
# 101   0.10793  0.0   8.56   0.0  0.520  6.195   54.4  2.7778   5.0  384.0
#
#      PTRATIO       B  LSTAT
# 0       19.1  378.09  17.93
# ...

# %%
test_pred=lm.predict(test)
# Out:
# C:\Users\odita\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - B
# - RAD
# Feature names seen at fit time, yet now missing:
# - BLACK
# - MEDV
#
#   warnings.warn(message, FutureWarning)

# %%
print(test_pred)
# Out:
# [5.961 5.987 6.103 6.251 6.069 5.963 6.758 6.047 7.104 5.986 6.728 7.333
#  5.935 6.266 5.155 6.312 6.301 6.833 6.8   6.03  5.976 5.608 5.648 5.404
#  6.854 4.963 6.02  6.426 5.854 7.185 5.926 6.781 4.652 6.014 6.575 7.236
#  6.169 4.906 6.852 6.315 5.887 6.38  7.241 5.427 6.29  6.376 6.152 5.783
#  6.718 5.905 6.185 7.287 5.454 6.728 6.421 5.898 6.516 5.565 6.12  6.358
#  5.67  6.219 7.82  5.856 6.341 6.43  6.606 4.138 5.39  6.739 5.985 6.114
#  5.952 6.939 5.99  8.78  6.193 4.368 5.709 6.375 6.113 4.903 6.343 6.579
#  6.279 6.009 8.375 6.162 7.923 6.943 7.079 6.251 5.631 6.202 6.629 7.135
#  6.059 6.101 5.836 6.167 5.597 6.195]
